# %% [markdown]
# # Kickstarter_survivors
# ### Sifan Liu

# %% [markdown]
# ## Set up and load data

# %%
# Load packages and set up
import numpy as np
import pandas as pd
import json
import glob

def CustomParser(data):
    import json
    try:
        j1 = json.loads(data)
        return j1
    except ValueError:
        pass

JSONconverters = {'location':CustomParser, 'category':CustomParser, 'creator':CustomParser}

# %%
# read data

# from csv =============================================
# all files --------------------------------------------
path = r'source/Kickstarter_2018-02-15T03_20_44_743Z'
all_files = glob.glob(path + "/*.csv")

df_from_each_file = (pd.read_csv(f,converters = JSONconverters) for f in all_files)
df = pd.concat(df_from_each_file, ignore_index = True)

# %%
# sample_data ------------------------------------------
# df = pd.read_csv('source/kickstarter_sample.csv', converters = JSONconverters)

# %%
# extract json information to columns
def JsonConcate(dataframe, column):
    temp = dataframe[column].apply(pd.Series)
    temp = temp.rename(columns = lambda x : column + '_' + str(x))
    dataframe = pd.concat([dataframe[:],temp[:]],axis =1)
    return dataframe

for col in ('location','category','creator'):
    df = JsonConcate(df,col)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195614 entries, 0 to 195613
# Data columns (total 62 columns):
# backers_count                195614 non-null int64
# blurb                        195603 non-null object
# category                     195614 non-null object
# converted_pledged_amount     195614 non-null int64
# country                      195614 non-null object
# created_at                   195614 non-null int64
# creator                      195614 non-null object
# currency                     195614 non-null object
# currency_symbol              195614 non-null object
# currency_trailing_code       195614 non-null bool
# current_currency             195614 non-null object
# deadline                     195614 non-null int64
# disable_communication        195614 non-null bool
# fx_rate                      195614 non-null float64
# goal                         195614 non-null float64
# id                           195614 non-null int64
# is_starrable                 195614 non-null bool
# launched_at                  195614 non-null int64
# name                         195613 non-null object
# photo                        195614 non-null object
# pledged                      195614 non-null float64
# profile                      195614 non-null object
# slug                         195614 non-null object
# source_url                   195614 non-null object
# spotlight                    195614 non-null bool
# staff_pick                   195614 non-null bool
# state                        195614 non-null object
# state_changed_at             195614 non-null int64
# static_usd_rate              195614 non-null float64
# urls                         195614 non-null object
# usd_pledged                  195614 non-null float64
# usd_type                     195398 non-null object
# location                     194264 non-null object
# friends                      168 non-null object
# is_backing                   168 non-null object
# is_starred                   168 non-null object
# permissions                  168 non-null object
# location_country             194264 non-null object
# location_displayable_name    194264 non-null object
# location_id                  194264 non-null float64
# location_is_root             194264 non-null object
# location_localized_name      194264 non-null object
# location_name                194264 non-null object
# location_short_name          194264 non-null object
# location_slug                193831 non-null object
# location_state               194219 non-null object
# location_type                194264 non-null object
# location_urls                194264 non-null object
# category_color               195614 non-null int64
# category_id                  195614 non-null int64
# category_name                195614 non-null object
# category_parent_id           179859 non-null float64
# category_position            195614 non-null int64
# category_slug                195614 non-null object
# category_urls                195614 non-null object
# creator_avatar               195614 non-null object
# creator_chosen_currency      281 non-null object
# creator_id                   195614 non-null int64
# creator_is_registered        195614 non-null bool
# creator_name                 195614 non-null object
# creator_slug                 56717 non-null object
# creator_urls                 195614 non-null object
# dtypes: bool(6), float64(7), int64(11), object(38)
# memory usage: 84.7+ MB

# %%
place2msa = pd.read_csv("source/place2msa.csv", encoding = 'latin-1')
# remove 'city'|'town'|'CDP'
place2msa['place'] = place2msa['PLACENAME'].str.replace(r'(\s\w+)$','')

place2msa.sample(5)
# Out:
#        Unnamed: 0 STATE  STATEFP  PLACEFP        PLACENAME  \
# 13543       13544    MI       26    31160     Gaastra city
# 13356       13357    MI       26    23500      Durand city
# 12520       12521    MA       25    52770    Pepperell CDP
# 34249       34250    TX       48      100      Abbott city
# 16484       16485    MN       27    29636  Hollandale city
#
#                           TYPE FUNCSTAT           cty_name cty_alt  FIPS_City  \
# 13543       County Subdivision        F        Iron County     NaN    2631160
# 13356       Incorporated Place        A  Shiawassee County     NaN    2623500
# 12520  Census Designated Place        S   Middlesex County     NaN    2552770
# 34249       Incorporated Place        A        Hill County     NaN    4800100
# 16484       Incorporated Place        A    Freeborn County     NaN    2729636
#
#           ...                           cbsa_name  \
# 13543     ...                                 NaN
# 13356     ...                          Owosso, MI
# 12520     ...      Boston-Cambridge-Newton, MA-NH
# 34249     ...                                 NaN
# 16484     ...                      Albert Lea, MN
#
#                          metro_micro  \
# 13543                            NaN
# 13356  Micropolitan Statistical Area
# 12520  Metropolitan Statistical Area
# 34249                            NaN
# 16484  Micropolitan Statistical Area
#
#                                        csa_name        st_name countyFIPS  \
# 13543                                       NaN            NaN        NaN
# 13356           Lansing-East Lansing-Owosso, MI       Michigan      155.0
# 12520  Boston-Worcester-Providence, MA-RI-NH-CT  Massachusetts       17.0
# 34249                                       NaN            NaN        NaN
# 16484                                       NaN      Minnesota       47.0
#
#        central_outlying     fips  top100  Frey52       place
# 13543               NaN      NaN     NaN     NaN     Gaastra
# 13356           Central  26155.0     0.0     0.0      Durand
# 12520           Central  25017.0     1.0     1.0   Pepperell
# 34249               NaN      NaN     NaN     NaN      Abbott
# 16484           Central  27047.0     0.0     0.0  Hollandale
#
# [5 rows x 21 columns]

# %%
## TODO

# merge population data

# %% [markdown]
# ## Clean Kickstarter dataset

# %%
# convert unix time
time_cols = ['created_at', 'deadline', 'state_changed_at','launched_at']
df[time_cols] = df[time_cols].apply(pd.to_datetime,unit='s')

# %%
# calculate duration
df['life'] = df['deadline'] - df['launched_at']
df['duration'] = df['state_changed_at'] - df['launched_at']
df['prep'] =  df['launched_at'] - df['created_at']

# df['state_changed_at'][0].year

# %%
# factorize project state
df['state'] = df['state'].astype('category')
pd.pivot_table(df, index = ['state'])
# Out:
#             backers_count  category_color  category_id  category_parent_id  \
# state
# canceled        14.587102    1.127952e+07   251.370169           12.062110
# failed          12.971290    1.171623e+07   217.489475           11.868382
# live            86.059191    1.030409e+07   143.125364           11.420201
# successful     251.701249    1.191508e+07   113.756898           11.720128
# suspended       25.078203    9.734057e+06   281.163062           12.978369
#
#             category_position  converted_pledged_amount    creator_id  \
# state
# canceled             6.537346               1743.798255  1.078425e+09
# failed               6.907461               1139.126898  1.073903e+09
# live                 6.517307               6966.336678  1.062947e+09
# successful           7.479788              20586.952318  1.072928e+09
# suspended            5.725458               3818.810316  1.090515e+09
#
#             creator_is_registered  currency_trailing_code  \
# state
# canceled                      1.0                0.819336
# failed                        1.0                0.844121
# live                          1.0                0.765998
# successful                    1.0                0.902621
# suspended                     1.0                0.795341
#
#             disable_communication   fx_rate           goal            id  \
# state
# canceled                      0.0  1.016327  129306.888268  1.081208e+09
# failed                        0.0  1.018013   87866.267453  1.077278e+09
# live                          0.0  0.993470   44983.583915  1.067016e+09
# successful                    0.0  1.016613   10119.826796  1.073564e+09
# suspended                     1.0  1.018514  248081.559068  1.107546e+09
#
#             is_starrable   location_id       pledged  spotlight  staff_pick  \
# state
# canceled        0.000000  3.405093e+06   2071.929268        0.0    0.034115
# failed          0.000000  3.492088e+06   1350.028128        0.0    0.035079
# live            0.939936  3.629417e+06  18937.739379        0.0    0.068063
# successful      0.000000  3.270084e+06  21753.086148        1.0    0.217335
# suspended       0.000000  3.151386e+06   4122.225191        0.0    0.000000
#
#             static_usd_rate   usd_pledged
# state
# canceled           1.018392   1745.899967
# failed             1.023096   1140.815263
# live               0.995623   6971.889767
# successful         1.020974  20589.072345
# suspended          1.018617   3804.140207

# %%
df['category_broad'] = df['category_slug'].str.extract(r'([^\/]+)', expand = False).astype('category')
df['category_broad'].describe()
# Out:
# count     222522
# unique        15
# top        music
# freq       30885
# Name: category_broad, dtype: object

# %%
# generate gender by first name
# STEP 1: strip first name
df['first_name'] = df['creator_name'].str.extract(r'([^\s]+)',expand = False).str.title()

# STEP 2: gender
# https://pypi.org/project/gender-guesser/
import gender_guesser.detector as gender
d = gender.Detector()

# STEP 3: apply
df['gender'] = df['first_name'].apply(d.get_gender)

pd.pivot_table(df, index = ['gender'],aggfunc = len)
# Out:
#                backers_count  blurb  category  category_color  category_id  \
# gender
# andy                    1997   1997      1997            1997         1997
# female                 35752  35752     35752           35752        35752
# male                   86090  86090     86090           86090        86090
# mostly_female           7861   7861      7861            7861         7861
# mostly_male             8303   8303      8303            8303         8303
# unknown                55611  55611     55611           55611        55611
#
#                category_name  category_parent_id  category_position  \
# gender
# andy                    1997              1997.0               1997
# female                 35752             35752.0              35752
# male                   86090             86090.0              86090
# mostly_female           7861              7861.0               7861
# mostly_male             8303              8303.0               8303
# unknown                55611             55611.0              55611
#
#                category_slug  category_urls    ...      slug  source_url  \
# gender                                         ...
# andy                    1997           1997    ...      1997        1997
# female                 35752          35752    ...     35752       35752
# male                   86090          86090    ...     86090       86090
# mostly_female           7861           7861    ...      7861        7861
# mostly_male             8303           8303    ...      8303        8303
# unknown                55611          55611    ...     55611       55611
#
#                spotlight  staff_pick  state  state_changed_at  \
# gender
# andy                1997        1997   1997              1997
# female             35752       35752  35752             35752
# male               86090       86090  86090             86090
# mostly_female       7861        7861   7861              7861
# mostly_male         8303        8303   8303              8303
# unknown            55611       55611  55611             55611
#
#                static_usd_rate   urls  usd_pledged  usd_type
# gender
# andy                    1997.0   1997       1997.0      1997
# female                 35752.0  35752      35752.0     35752
# male                   86090.0  86090      86090.0     86090
# mostly_female           7861.0   7861       7861.0      7861
# mostly_male             8303.0   8303       8303.0      8303
# unknown                55611.0  55611      55611.0     55611
#
# [6 rows x 66 columns]

# %%
# match place to MSA

df = pd.merge(df,place2msa,how = 'left',
              left_on=['location_state','location_localized_name'],
              right_on=['STATE','place'])

# %% [markdown]
# ## Summary: selected columns

# %%
# keep selected columns
col = ['location_country','location_state','location_localized_name','cbsa_name','top100',
       'backers_count','goal','pledged','creator_name','gender','category_broad','category_name',
       'launched_at','deadline','state_changed_at','state','life','duration','prep']

df_sample = df[col]

# table = pd.pivot_table(df_sample, index=["location_state","location_country"], aggfunc = [np.mean,len])
# table.query('location_country == ["US"]')

# %%
# df = pd.read_pickle("master")

# %%
# df_sample.to_pickle("sample")
df_sample.to_pickle("master")
