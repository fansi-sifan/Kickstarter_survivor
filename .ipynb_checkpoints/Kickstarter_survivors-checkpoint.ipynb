# %% [markdown]
# # Kickstarter_survivors
# ### Sifan Liu

# %% [markdown]
# ## Set up and load data

# %%
# Load packages and set up
import numpy as np
import pandas as pd
import json
import glob

def CustomParser(data):
    import json
    try:
        j1 = json.loads(data)
        return j1
    except ValueError:
        pass

JSONconverters = {'location':CustomParser, 'category':CustomParser, 'creator':CustomParser}

# %%
# read data from csv

def ReadAllfiles(path):
    all_files = glob.glob(path + "/*.csv")
    df_from_each_file = (pd.read_csv(f,converters = JSONconverters) for f in all_files)
    df = pd.concat(df_from_each_file, ignore_index = True)
    return df

path2018 = r'../datasample/Kickstarter_2018-02-15T03_20_44_743Z'
# path2017 = r'source/Kickstarter_2017-02-15T22_22_48_377Z'
# path2015 = r'source/Kickstarter_2015-12-17T12_09_06_107Z'

# df2015 = ReadAllfiles(path2015)
# df2017 = ReadAllfiles(path2017)
df2018 = ReadAllfiles(path2018)

# df = pd.concat([df2018, df2017, df2015]).drop_duplicates(["id"]).reset_index(drop=True)

# %%
df = df2018.drop_duplicates(['launched_at'])
df.info()
# sample_data ------------------------------------------
# df = pd.read_csv('source/kickstarter_sample.csv', converters = JSONconverters)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177647 entries, 0 to 195613
# Data columns (total 37 columns):
# backers_count               177647 non-null int64
# blurb                       177637 non-null object
# category                    177647 non-null object
# converted_pledged_amount    177647 non-null int64
# country                     177647 non-null object
# created_at                  177647 non-null int64
# creator                     177647 non-null object
# currency                    177647 non-null object
# currency_symbol             177647 non-null object
# currency_trailing_code      177647 non-null bool
# current_currency            177647 non-null object
# deadline                    177647 non-null int64
# disable_communication       177647 non-null bool
# fx_rate                     177647 non-null float64
# goal                        177647 non-null float64
# id                          177647 non-null int64
# is_starrable                177647 non-null bool
# launched_at                 177647 non-null int64
# name                        177646 non-null object
# photo                       177647 non-null object
# pledged                     177647 non-null float64
# profile                     177647 non-null object
# slug                        177647 non-null object
# source_url                  177647 non-null object
# spotlight                   177647 non-null bool
# staff_pick                  177647 non-null bool
# state                       177647 non-null object
# state_changed_at            177647 non-null int64
# static_usd_rate             177647 non-null float64
# urls                        177647 non-null object
# usd_pledged                 177647 non-null float64
# usd_type                    177647 non-null object
# location                    176713 non-null object
# friends                     83 non-null object
# is_backing                  83 non-null object
# is_starred                  83 non-null object
# permissions                 83 non-null object
# dtypes: bool(5), float64(5), int64(7), object(20)
# memory usage: 45.6+ MB

# %%
# extract json information to columns
def JsonConcate(dataframe, column):
    temp = dataframe[column].apply(pd.Series)
    temp = temp.rename(columns = lambda x : column + '_' + str(x))
    dataframe = pd.concat([dataframe[:],temp[:]],axis =1)
    return dataframe

for col in ('location','category','creator'):
    df = JsonConcate(df,col)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177647 entries, 0 to 195613
# Data columns (total 62 columns):
# backers_count                177647 non-null int64
# blurb                        177637 non-null object
# category                     177647 non-null object
# converted_pledged_amount     177647 non-null int64
# country                      177647 non-null object
# created_at                   177647 non-null int64
# creator                      177647 non-null object
# currency                     177647 non-null object
# currency_symbol              177647 non-null object
# currency_trailing_code       177647 non-null bool
# current_currency             177647 non-null object
# deadline                     177647 non-null int64
# disable_communication        177647 non-null bool
# fx_rate                      177647 non-null float64
# goal                         177647 non-null float64
# id                           177647 non-null int64
# is_starrable                 177647 non-null bool
# launched_at                  177647 non-null int64
# name                         177646 non-null object
# photo                        177647 non-null object
# pledged                      177647 non-null float64
# profile                      177647 non-null object
# slug                         177647 non-null object
# source_url                   177647 non-null object
# spotlight                    177647 non-null bool
# staff_pick                   177647 non-null bool
# state                        177647 non-null object
# state_changed_at             177647 non-null int64
# static_usd_rate              177647 non-null float64
# urls                         177647 non-null object
# usd_pledged                  177647 non-null float64
# usd_type                     177647 non-null object
# location                     176713 non-null object
# friends                      83 non-null object
# is_backing                   83 non-null object
# is_starred                   83 non-null object
# permissions                  83 non-null object
# location_country             176713 non-null object
# location_displayable_name    176713 non-null object
# location_id                  176713 non-null float64
# location_is_root             176713 non-null object
# location_localized_name      176713 non-null object
# location_name                176713 non-null object
# location_short_name          176713 non-null object
# location_slug                176303 non-null object
# location_state               176675 non-null object
# location_type                176713 non-null object
# location_urls                176713 non-null object
# category_color               177647 non-null int64
# category_id                  177647 non-null int64
# category_name                177647 non-null object
# category_parent_id           161893 non-null float64
# category_position            177647 non-null int64
# category_slug                177647 non-null object
# category_urls                177647 non-null object
# creator_avatar               177647 non-null object
# creator_chosen_currency      213 non-null object
# creator_id                   177647 non-null int64
# creator_is_registered        177647 non-null bool
# creator_name                 177647 non-null object
# creator_slug                 49977 non-null object
# creator_urls                 177647 non-null object
# dtypes: bool(6), float64(7), int64(11), object(38)
# memory usage: 78.3+ MB

# %%
place2msa = pd.read_csv("source/place2msa.csv", encoding = 'latin-1')
# remove 'city'|'town'|'CDP'
place2msa['place'] = place2msa['PLACENAME'].str.replace(r'(\s\w+)$','')

place2msa.sample(5)
# Out:
#        Unnamed: 0 STATE  STATEFP  PLACEFP            PLACENAME  \
# 17918       17919    MN       27    58936         Scanlon city
# 546           547    AL        1    78984            Vina town
# 37108       37109    VA       51    59384           Onley town
# 21079       21080    NH       33     3460      Barrington town
# 33031       33032    RI       44    77720  West Greenwich town
#
#                      TYPE FUNCSTAT          cty_name cty_alt  FIPS_City  \
# 17918  County Subdivision        F    Carlton County     NaN    2758936
# 546    Incorporated Place        A   Franklin County     NaN     178984
# 37108  Incorporated Place        A   Accomack County     NaN    5159384
# 21079  County Subdivision        A  Strafford County     NaN    3303460
# 33031  County Subdivision        A       Kent County     NaN    4477720
#
#             ...                             cbsa_name  \
# 17918       ...                         Duluth, MN-WI
# 546         ...                                   NaN
# 37108       ...                                   NaN
# 21079       ...        Boston-Cambridge-Newton, MA-NH
# 33031       ...             Providence-Warwick, RI-MA
#
#                          metro_micro  \
# 17918  Metropolitan Statistical Area
# 546                              NaN
# 37108                            NaN
# 21079  Metropolitan Statistical Area
# 33031  Metropolitan Statistical Area
#
#                                        csa_name        st_name countyFIPS  \
# 17918                                       NaN      Minnesota       17.0
# 546                                         NaN            NaN        NaN
# 37108                                       NaN            NaN        NaN
# 21079  Boston-Worcester-Providence, MA-RI-NH-CT  New Hampshire       17.0
# 33031  Boston-Worcester-Providence, MA-RI-NH-CT   Rhode Island        3.0
#
#        central_outlying     fips  top100  Frey52           place
# 17918          Outlying  27017.0     0.0     0.0         Scanlon
# 546                 NaN      NaN     NaN     NaN            Vina
# 37108               NaN      NaN     NaN     NaN           Onley
# 21079          Outlying  33017.0     1.0     1.0      Barrington
# 33031           Central  44003.0     1.0     1.0  West Greenwich
#
# [5 rows x 21 columns]

# %%
## TODO

# merge population data

# %% [markdown]
# ## Clean Kickstarter dataset

# %%
# convert unix time
time_cols = ['created_at', 'deadline', 'state_changed_at','launched_at']
df[time_cols] = df[time_cols].apply(pd.to_datetime,unit='s')

# %%
# calculate duration
df['life'] = df['deadline'] - df['launched_at']
df['duration'] = df['state_changed_at'] - df['launched_at']
df['prep'] =  df['launched_at'] - df['created_at']

# df['state_changed_at'][0].year

# %%
# factorize project state
df['state'] = df['state'].astype('category')
pd.pivot_table(df, index = ['state'])
# Out:
#             backers_count  category_color  category_id  category_parent_id  \
# state
# canceled        14.595892    1.127758e+07   251.300840           12.062188
# failed          13.024047    1.180186e+07   216.307880           11.858619
# live            80.914510    1.075089e+07   136.398021           11.306412
# successful     235.938560    1.225656e+07   113.349221           11.649377
# suspended       25.078203    9.734057e+06   281.163062           12.978369
#
#             category_position  converted_pledged_amount    creator_id  \
# state
# canceled             6.531548               1743.495574  1.078063e+09
# failed               6.932738               1144.908184  1.074044e+09
# live                 6.444191               6546.533486  1.062190e+09
# successful           7.542104              19338.581673  1.073328e+09
# suspended            5.725458               3818.810316  1.090515e+09
#
#             creator_is_registered  currency_trailing_code  \
# state
# canceled                      1.0                0.819110
# failed                        1.0                0.843950
# live                          1.0                0.762303
# successful                    1.0                0.895925
# suspended                     1.0                0.795341
#
#             disable_communication   fx_rate           goal            id  \
# state
# canceled                      0.0  1.016370  129421.320380  1.081303e+09
# failed                        0.0  1.017990   88373.330867  1.077541e+09
# live                          0.0  0.992477   46928.084221  1.068464e+09
# successful                    0.0  1.017314    9967.393967  1.073053e+09
# suspended                     1.0  1.018514  248081.559068  1.107546e+09
#
#             is_starrable   location_id       pledged  spotlight  staff_pick  \
# state
# canceled         0.00000  3.406730e+06   2071.816492        0.0    0.034158
# failed           0.00000  3.493788e+06   1357.625354        0.0    0.035118
# live             0.93861  3.686239e+06  17144.056481        0.0    0.065195
# successful       0.00000  3.293887e+06  20730.996588        1.0    0.211469
# suspended        0.00000  3.151386e+06   4122.225191        0.0    0.000000
#
#             static_usd_rate   usd_pledged
# state
# canceled           1.018427   1745.585310
# failed             1.022837   1146.593782
# live               1.000137   6660.775202
# successful         1.021316  19340.536221
# suspended          1.018617   3804.140207

# %%
df['category_broad'] = df['category_slug'].str.extract(r'([^\/]+)', expand = False).astype('category')
df['category_broad'].describe()
# Out:
# count     177647
# unique        15
# top        music
# freq       24697
# Name: category_broad, dtype: object

# %%
# generate gender by first name
# STEP 1: strip first name
df['first_name'] = df['creator_name'].str.extract(r'([^\s]+)',expand = False).str.title()


# STEP 2: gender
# https://pypi.org/project/gender-guesser/
import gender_guesser.detector as gender
from gender_detector import GenderDetector
d = gender.Detector()
g = GenderDetector('us')

# STEP 3: apply
df['gender'] = df['first_name'].apply(d.get_gender)
df['Gender'] = df['first_name'].apply(g.getGender)

pd.crosstab(df['gender'], df['Gender'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-3a83a98d1b43> in <module>()
#       5 # STEP 2: gender
#       6 # https://pypi.org/project/gender-guesser/
# ----> 7 import gender_guesser.detector as gender
#       8 from gender_detector import GenderDetector
#       9 d = gender.Detector()
#
# ModuleNotFoundError: No module named 'gender_guesser'

# %%
# match place to MSA

df['location_place'] = df['location_short_name'].str.extract(r'([^\,]+)',expand = False)

merge = pd.merge(df, place2msa, how = 'left',
                  left_on=['location_state','location_place'],
                  right_on=['STATE','place'])

# %%
# check for the unmatched places

temp = merge[merge['top100'].isnull()]
temp = temp[temp['location_country'] == "US"]

missing = pd.DataFrame(temp.groupby(['location_place','location_state']).count()).reset_index()

# %% [markdown]
# ## Summary: selected columns

# %%
# keep selected columns
col = ['location_country','location_state','location_localized_name','location_name','cbsa_name','top100',
       'backers_count','goal','pledged','creator_name','gender','category_broad','category_name',
       'launched_at','deadline','state_changed_at','state','life','duration','prep']

df_sample = df[col]

# table = pd.pivot_table(df_sample, index=["location_state","location_country"], aggfunc = [np.mean,len])
# table.query('location_country == ["US"]')

# %%
# df = pd.read_pickle("master")

# %%
# df_sample.to_pickle("sample")
df_sample.to_pickle("master")

# %%
df['state'].value_counts()
# Out:
# successful    105055
# failed         82220
# canceled        9764
# live            4358
# suspended        678
# Name: state, dtype: int64

# %%
df.shape
# Out:
# (202075, 89)

# %%
# SETUP
import requests

API_KEY = 'AIzaSyB-ZUZ-8gz59WjahkqORGbZu__NrPZZR_k'
addresses = (missing['location_place'] +','+ missing['location_state'] + ',US').tolist()

def get_google_results(address, api_key = None):
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    results = requests.get(geocode_url)
    results = results.json()
    if len(results['results']) == 0:
        output = {'address_county':None,
                 'address_state':None}
    else:
        answer = results['results'][0]
        output = {'address_county':answer.get('address_components')[1].get('short_name'),
                 'address_state':answer.get('address_components')[2].get('short_name')}
        
    return output

# %%
 get_google_results("East Village, NY,US", API_KEY)
# Out:
# {'address_county': None, 'address_state': None}

# %%
results = []

for address in addresses:
    geocoded = False
    while geocoded is not True:
        try:
            geocode_result = get_google_results(address, API_KEY)
        except Exception as e:
            geocoded = True
            
        results.append(geocode_result)
        geocoded = True
            
output = pd.concat([missing, pd.DataFrame(results)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-d632e5699456> in <module>()
#       5     while geocoded is not True:
#       6         try:
# ----> 7             geocode_result = get_google_results(address, API_KEY)
#       8         except Exception as e:
#       9             geocoded = True
#
# <ipython-input-30-4d68b3b85437> in get_google_results(address, api_key)
#      10         geocode_url = geocode_url + "&key={}".format(api_key)
#      11
# ---> 12     results = requests.get(geocode_url)
#      13     results = results.json()
#      14     if len(results['results']) ==0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     307     if ca_certs or ca_cert_dir:
#     308         try:
# --> 309             context.load_verify_locations(ca_certs, ca_cert_dir)
#     310         except IOError as e:  # Platform-specific: Python 2.6, 2.7, 3.2
#     311             raise SSLError(e)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in load_verify_locations(self, cafile, capath, cadata)
#     411         if capath is not None:
#     412             capath = capath.encode('utf-8')
# --> 413         self._ctx.load_verify_locations(cafile, capath)
#     414         if cadata is not None:
#     415             self._ctx.load_verify_locations(BytesIO(cadata))
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in load_verify_locations(self, cafile, capath)
#     664
#     665         load_result = _lib.SSL_CTX_load_verify_locations(
# --> 666             self._context, cafile, capath
#     667         )
#     668         if not load_result:
#
# KeyboardInterrupt:

# %%
temp.groupby(['location_localized_name','address_county','address_state'])['goal'].count().nlargest(50)

# %%
temp = temp.isnull().sum()

# %%
temp
# Out:
# backers_count                  0
# blurb                          0
# category                       0
# converted_pledged_amount       0
# country                        0
# created_at                     0
# creator                        0
# currency                       0
# currency_symbol                0
# currency_trailing_code         0
# current_currency               0
# deadline                       0
# disable_communication          0
# fx_rate                        0
# goal                           0
# id                             0
# is_starrable                   0
# launched_at                    0
# name                           0
# photo                          0
# pledged                        0
# profile                        0
# slug                           0
# source_url                     0
# spotlight                      0
# staff_pick                     0
# state                          0
# state_changed_at               0
# static_usd_rate                0
# urls                           0
#                             ...
# creator_is_registered          0
# creator_name                   0
# creator_slug                6014
# creator_urls                   0
# life                           0
# duration                       0
# prep                           0
# category_broad                 0
# location_place                 0
# Unnamed: 0                  8318
# STATE                       8318
# STATEFP                     8318
# PLACEFP                     8318
# PLACENAME                   8318
# TYPE                        8318
# FUNCSTAT                    8318
# cty_name                    8318
# cty_alt                     8318
# FIPS_City                   8318
# cbsa                        8318
# cbsa_name                   8318
# metro_micro                 8318
# csa_name                    8318
# st_name                     8318
# countyFIPS                  8318
# central_outlying            8318
# fips                        8318
# top100                      8318
# Frey52                      8318
# place                       8318
# Length: 88, dtype: int64
